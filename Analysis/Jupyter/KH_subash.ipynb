# %%
import TurbPy as tb
from TurbPy.imports import *

# %%
deck = 'KH_subash/'

dirs = '/pscratch/sd/g/goodwill/' + deck

figs = '/pscratch/sd/g/goodwill/Fig/' + deck

info = tb.get_vpic_info(dirs)
times = tb.get_times(dirs)
en_out = tb.read_energies(dirs)/(info['Lx/de'] * info['Ly/de'] * info['Lz/de'])

twci_out = np.linspace(0, times[-1] * info['dt*wci'], len(en_out['EM']))
twci = np.linspace(0, times[-1] * info['dt*wci'], len(times))

twce_out = np.linspace(0, times[-1] * info['dt*wce'], len(en_out['EM']))
twce = np.linspace(0, times[-1] * info['dt*wce'], len(times))

en = tb.read_calc_energies(dirs)/(info['Lx/de'] * info['Ly/de'] * info['Lz/de'])

dEM_s = en['EM'] - en['EM'][0]
dEE_s = en['EE'] - en['EE'][0]

dEi_s   = (en['Efi']  + en['Ethi']) - (en['Efi'] + en['Ethi'])[0]
dEthi_s = en['Ethi'] - en['Ethi'][0]
dEfi_s = en['Efi'] - en['Efi'][0]

dEe_s = (en['Efe'] + en['Ethe']) - (en['Efe'] + en['Ethe'])[0]
dEthe_s = en['Ethe'] - en['Ethe'][0]
dEfe_s = en['Efe'] - en['Efe'][0]

# %%
deck = 'KH/'
dirs = '/pscratch/sd/g/goodwill/' + deck
# figs = '/pscratch/sd/g/goodwill/Fig/' + deck
info = tb.get_vpic_info(dirs)
times = tb.get_times(dirs)
en_out = tb.read_energies(dirs)/(info['Lx/de'] * info['Ly/de'] * info['Lz/de'])
twci_out = np.linspace(0, times[-1] * info['dt*wci'], len(en_out['EM']))
twciJ = np.linspace(0, times[-1] * info['dt*wci'], len(times))

lx = info['Lx/di']
ly = info['Ly/di']
nx = int(info['nx'])
ny = int(info['ny'])
en = tb.read_calc_energies(dirs)/(info['Lx/de'] * info['Ly/de'] * info['Lz/de'])

dEM = en['EM'] - en['EM'][0]
dEE = en['EE'] - en['EE'][0]

dEi = (en['Efi']  + en['Ethi']) - (en['Efi'] + en['Ethi'])[0]
dEthi = en['Ethi'] - en['Ethi'][0]
dEfi = en['Efi'] - en['Efi'][0]

dEe = (en['Efe'] + en['Ethe']) - (en['Efe'] + en['Ethe'])[0]
dEthe = en['Ethe'] - en['Ethe'][0]
dEfe = en['Efe'] - en['Efe'][0]

# %%
fig, axs = plt.subplots(3,1, figsize=(15, 10), sharex = True, layout='constrained')
EbJ = axs[0].plot(twciJ, dEM + dEE, color = 'darkorange', marker = 'x' , label = r'$\delta E_m$')
EbS = axs[0].plot(twci, dEM_s + dEE_s, color = 'blue', marker = 'x' , label = r'$\delta E_m$')
axs[0].ticklabel_format(axis = 'y',style = 'sci', scilimits = (0,0))
axs[0].ticklabel_format(axis = 'y',style = 'sci', scilimits = (0,0))
axs[0].ticklabel_format(axis = 'y',style = 'sci', scilimits = (0,0))
axs[0].ticklabel_format(axis = 'y',style = 'sci', scilimits = (0,0))
axs[0].ticklabel_format(axis = 'y',style = 'sci', scilimits = (0,0))
axs[0].ticklabel_format(axis = 'y',style = 'sci', scilimits = (0,0))
axs[0].ticklabel_format(axis = 'y',style = 'sci', scilimits = (0,0))
axs[0].ticklabel_format(axis = 'y',style = 'sci', scilimits = (0,0))
leg1 = axs[0].legend(EbS, [r'$\delta E_m$'], loc = 'upper left', title = 'Subash', fontsize = 12)
leg2 = axs[0].legend(EbJ, [r'$\delta E_m$'], loc = 'lower left', title = 'Josh', fontsize = 12)
fig.add_artist(leg1)
fig.add_artist(leg2)
axs[0].xaxis.set_minor_locator(AutoMinorLocator())
axs[0].yaxis.set_minor_locator(AutoMinorLocator())
axs[0].tick_params(which='both', width=2, labelsize = 20, right = True, direction = 'in')
axs[0].tick_params(which='major', length=10, top = True, right =True)
axs[0].tick_params(which='minor', length=5 , top = True, right =True)
axs[0].grid()


dEiJ, =  axs[1].plot(twciJ, dEi,     color = 'darkorchid', marker = 'x' , label = r'$\delta E_i$')
dEfiJ, = axs[1].plot(twciJ, dEfi,    color = 'purple',    marker = 'x' , linestyle = '--', label = r'$\delta E^{f}_i$')
dEthiJ,= axs[1].plot(twciJ, dEthi,   color = 'magenta',   marker = 'x' , linestyle = '--', label = r'$\delta E^{th}_i$')
dEiS, = axs[1].plot(twci, dEi_s,     color = 'darkgreen', marker = 'x' , label = r'$\delta E_i$')
dEfiS, =axs[1].plot(twci, dEfi_s,    color = 'limegreen',marker = 'x' , linestyle = '--', label = r'$\delta E^{f}_i$')
dEthiS,=axs[1].plot(twci, dEthi_s,   color = 'lime',     marker = 'x' , linestyle = '--', label = r'$\delta E^{th}_i$')
leg1 = axs[1].legend(handles = [dEiJ, dEfiJ, dEthiJ], loc = 'upper left', title = 'Josh', fontsize = 12)
leg2 = axs[1].legend(handles = [dEiS, dEfiS, dEthiS], loc = 'lower left', title = 'Subash', fontsize = 12)
axs[1].add_artist(leg1)
axs[1].add_artist(leg2)
axs[1].ticklabel_format(axis = 'y',style = 'sci', scilimits = (0,0))
axs[1].ticklabel_format(axis = 'y',style = 'sci', scilimits = (0,0))
axs[1].ticklabel_format(axis = 'y',style = 'sci', scilimits = (0,0))
axs[1].ticklabel_format(axis = 'y',style = 'sci', scilimits = (0,0))
axs[1].xaxis.set_minor_locator(AutoMinorLocator())
axs[1].yaxis.set_minor_locator(AutoMinorLocator())
axs[1].tick_params(which='both', width=2, labelsize = 20, right = True, direction = 'in')
axs[1].tick_params(which='major', length=10, top = True, right =True)
axs[1].tick_params(which='minor', length=5 , top = True, right =True)
axs[1].grid()

dEeJ, = axs[2].plot(twciJ, dEe,   color = 'darkorchid', marker = 'x', label = r'$\delta E_e$')
dEfeJ, =axs[2].plot(twciJ, dEfe,  color = 'purple',     marker = 'x' ,linestyle = '--', label = r'$\delta E^{f}_e$')
dEtheJ,=axs[2].plot(twciJ, dEthe, color = 'magenta',    marker = 'x' ,linestyle = '--', label = r'$\delta E^{th}_e$')
dEeS, = axs[2].plot(twci, dEe_s,   color = 'darkgreen', marker = 'x', label = r'$\delta E_e$')
dEfeS, =axs[2].plot(twci, dEfe_s,  color = 'limegreen', marker = 'x' ,linestyle = '--', label = r'$\delta E^{f}_e$')
dEtheS,=axs[2].plot(twci, dEthe_s, color = 'lime',        marker = 'x' ,linestyle = '--', label = r'$\delta E^{th}_e$')
axs[2].ticklabel_format(axis = 'y',style = 'sci', scilimits = (0,0))
axs[2].ticklabel_format(axis = 'y',style = 'sci', scilimits = (0,0))
axs[2].ticklabel_format(axis = 'y',style = 'sci', scilimits = (0,0))
axs[2].ticklabel_format(axis = 'y',style = 'sci', scilimits = (0,0))
leg1 = axs[2].legend(handles = [dEeJ, dEfeJ, dEtheJ], loc = 'upper left', title = 'Josh', fontsize = 12)
leg2 = axs[2].legend(handles = [dEeS, dEfeS, dEtheS], loc = 'lower left', title = 'Subash', fontsize = 12)
axs[2].add_artist(leg1)
axs[2].add_artist(leg2)
axs[2].xaxis.set_minor_locator(AutoMinorLocator())
axs[2].yaxis.set_minor_locator(AutoMinorLocator())
axs[2].tick_params(which='both', width=2, labelsize = 20, right = True, direction = 'in')
axs[2].tick_params(which='major', length=10, top = True, right =True)
axs[2].tick_params(which='minor', length=5 , top = True, right =True)
axs[2].grid()

fig.supylabel(r'$\delta E \left[ \frac{m_e c^2}{d_e^3} \right] $', size = 25)
fig.supxlabel(r'$ t \omega_{ci} \left[ \frac{e B_0}{m_i c} \right]$', size = 25)

plt.savefig(figs + f'dE_comp_{deck[:-1]}.jpg', dpi = 400)

# %%
fig, axs = plt.subplots(1,1, figsize=(15, 10), sharex = True, layout='constrained')
axs.plot(twci, (dEM + dEE)/(dEM_s + dEE_s), color = 'darkorange', marker = 'x' , label = r'$\delta E_m$')
axs.plot(twci, dEi/dEi_s,     color = 'darkorchid', marker = 'x' , label = r'$\delta E_i$')
axs.plot(twci, dEfi/dEfi_s, color = 'purple',    marker = 'x' , linestyle = '--', label = r'$\delta E^{f}_i$')
axs.plot(twci, dEthi/dEthi_s,color = 'magenta',   marker = 'x' , linestyle = '--', label = r'$\delta E^{th}_i$')
axs.plot(twci, dEe/dEe_s,   color = 'darkgreen', marker = 'x', label = r'$\delta E_e$')
axs.plot(twci, dEfe/dEfe_s,  color = 'limegreen'   , marker = 'x' ,linestyle = '--', label = r'$\delta E^{f}_e$')
axs.plot(twci, dEthe/dEthe_s, color = 'lime', marker = 'x' ,linestyle = '--', label = r'$\delta E^{th}_e$')
axs.ticklabel_format(axis = 'y',style = 'sci', scilimits = (0,0))
axs.ticklabel_format(axis = 'y',style = 'sci', scilimits = (0,0))
axs.ticklabel_format(axis = 'y',style = 'sci', scilimits = (0,0))
axs.ticklabel_format(axis = 'y',style = 'sci', scilimits = (0,0))
axs.legend(loc = 'upper left', fontsize = 18)
axs.legend(loc = 'lower left', fontsize = 12)
axs.xaxis.set_minor_locator(AutoMinorLocator())
axs.yaxis.set_minor_locator(AutoMinorLocator())
axs.tick_params(which='both', width=2, labelsize = 20, right = True, direction = 'in')
axs.tick_params(which='major', length=10, top = True, right =True)
axs.tick_params(which='minor', length=5 , top = True, right =True)
fig.supylabel(r'$\frac{\delta E^J}{\delta E^S} $', size = 25)
fig.supxlabel(r'$ t \omega_{ci} \left[ \frac{e B_0}{m_i c} \right]$', size = 25)

axs.grid()
plt.savefig(figs + f'dE_ratio_{deck[:-1]}.jpg', dpi = 400)
